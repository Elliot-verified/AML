# %%
# pipeline.py

from __future__ import annotations

from dataclasses import dataclass, asdict
from pathlib import Path
import json
from typing import Dict, List

import pandas as pd
import matplotlib.pyplot as plt

from Bio import SeqIO, pairwise2

from PepMLM_gen_scripts.pepmlm_generate_fast import PepMLMConfig, run_pepmlm
from MetaLATTE_gen_scripts.run_metalatte_fasta import run_metalatte_on_fasta


# ============================================================
# CONFIG DATA STRUCTURES
# ============================================================

@dataclass
class SeedSet:
    name: str          # e.g. "pb_mer_operon"
    fasta_path: Path   # path to seeds fasta file


@dataclass
class PepMLMParams:
    n_variants_per_seed: int = 20
    fraction_mask: float = 0.10
    topk_per_mask: int = 5          
    max_len: int = 200
    batch_size: int = 8


@dataclass
class RunConfig:
    """
    A single experiment configuration (one 'run'):
      - same PepMLM params for all seed sets
      - novelty threshold, etc.
    """
    name: str
    out_dir: Path
    pepmlm_params: PepMLMParams
    novelty_identity_threshold: float = 0.95  # e.g. < 70% identity to be 'novel'
    top_k_variants: int = 200


# ============================================================
# UTILS
# ============================================================

def load_fasta_as_dict(fasta_path: Path) -> Dict[str, str]:
    """Return {id: sequence} from a FASTA file."""
    records = SeqIO.parse(str(fasta_path), "fasta")
    return {r.id: str(r.seq) for r in records}


def max_identity_to_any_seed(seq: str, seed_seqs: List[str]) -> float:
    """
    Compute max sequence identity between seq and any seed sequence.
    Simple global alignment + percent identity.
    """
    max_id = 0.0
    for s in seed_seqs:
        aln = pairwise2.align.globalxx(seq, s, one_alignment_only=True)[0]
        matches = sum(a == b for a, b in zip(aln.seqA, aln.seqB))
        length = max(len(aln.seqA.replace("-", "")), len(aln.seqB.replace("-", "")))
        if length == 0:
            continue
        ident = matches / length
        if ident > max_id:
            max_id = ident
    return max_id


def compute_binding_metrics(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add binding_capacity and best_metal columns from MetaLATTE prob_* columns.
    Assumes columns like prob_Pb, prob_Hg, prob_Non_binding, etc.
    """
    metal_cols = [
        c for c in df.columns
        if c.startswith("prob_") and "Non" not in c and "non" not in c
    ]
    if not metal_cols:
        raise ValueError("No metal prob_ columns found in MetaLATTE output.")

    df["binding_capacity"] = df[metal_cols].max(axis=1)
    df["best_metal"] = df[metal_cols].idxmax(axis=1).str.replace("prob_", "")
    return df


# ============================================================
# CORE PIPELINE FOR ONE SEED SET WITHIN A RUN
# ============================================================

def run_for_seed_set(seed: SeedSet, run_cfg: RunConfig) -> pd.DataFrame:
    """
    Run PepMLM + MetaLATTE for a single seed set within a run,
    compute novelty and binding metrics, and return a dataframe.
    """
    run_dir = run_cfg.out_dir
    run_dir.mkdir(parents=True, exist_ok=True)

    seed_subdir = run_dir / f"seed_{seed.name}"
    seed_subdir.mkdir(exist_ok=True)

    # 1. Generate variants with PepMLM
    variants_fasta = seed_subdir / "generated_variants.fasta"

    pep_cfg = PepMLMConfig(
        fasta_in=seed.fasta_path,
        fasta_out=variants_fasta,
        n_variants_per_seed=run_cfg.pepmlm_params.n_variants_per_seed,
        fraction_mask=run_cfg.pepmlm_params.fraction_mask,
        topk_per_mask=run_cfg.pepmlm_params.topk_per_mask,
        max_len=run_cfg.pepmlm_params.max_len,
        batch_size=run_cfg.pepmlm_params.batch_size,
    )
    print(f"[{run_cfg.name}] Running PepMLM for seed set '{seed.name}'")
    run_pepmlm(pep_cfg)

    # 2. Run MetaLATTE on generated variants
    metalatte_csv = seed_subdir / "metalatte_predictions.csv"
    print(f"[{run_cfg.name}] Running MetaLATTE for seed set '{seed.name}'")
    run_metalatte_on_fasta(
        fasta_path=str(variants_fasta),
        out_csv_path=str(metalatte_csv),
    )

    df = pd.read_csv(metalatte_csv)

    # 3. Add binding metrics
    df = compute_binding_metrics(df)

    # 4. Compute novelty (max identity vs any seed sequence)
    seed_seqs = list(load_fasta_as_dict(seed.fasta_path).values())
    print(f"[{run_cfg.name}] Computing novelty vs seeds for '{seed.name}' "
          f"(threshold: {run_cfg.novelty_identity_threshold:.2f})")

    # assume MetaLATTE output has a 'sequence' column (adjust if needed)
    if "sequence" not in df.columns:
        raise ValueError(
            "Expected a 'sequence' column in MetaLATTE output; "
            "adjust code if it's named differently."
        )

    identities = []
    for seq in df["sequence"]:
        identities.append(max_identity_to_any_seed(seq, seed_seqs))
    df["max_identity_to_seed"] = identities
    df["is_novel"] = df["max_identity_to_seed"] < run_cfg.novelty_identity_threshold

    # annotate with seed set & run name
    df["seed_set"] = seed.name
    df["run_name"] = run_cfg.name

    # 5. Save per-seed-set top variants if desired
    top_df = df.sort_values("binding_capacity", ascending=False).head(run_cfg.top_k_variants)
    top_df.to_csv(seed_subdir / "top_variants.csv", index=False)

    # 6. Make a simple novelty / identity histogram plot
    plots_dir = run_dir / "plots"
    plots_dir.mkdir(exist_ok=True)
    plt.figure()
    plt.hist(df["max_identity_to_seed"], bins=30)
    plt.xlabel("Max sequence identity to any seed")
    plt.ylabel("Count of generated variants")
    plt.title(f"{run_cfg.name} – {seed.name} – similarity to seeds")
    plt.tight_layout()
    img_path = plots_dir / f"identity_hist_{seed.name}.png"
    plt.savefig(img_path, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"[{run_cfg.name}] Saved similarity histogram → {img_path}")

    return df


# ============================================================
# RUNNING ONE EXPERIMENT (ALL SEED FILES AT ONCE)
# ============================================================

def run_experiment(seed_sets: List[SeedSet], run_cfg: RunConfig) -> None:
    """
    Run a full experiment:
      - all seed sets with the same PepMLM hyperparams,
      - aggregate into a single CSV,
      - compute per-seed summaries.
    """
    print("=" * 70)
    print(f"Running experiment: {run_cfg.name}")
    print("=" * 70)

    run_cfg.out_dir.mkdir(parents=True, exist_ok=True)

    # Save run config for reproducibility
    with open(run_cfg.out_dir / "run_config.json", "w") as f:
        json.dump(asdict(run_cfg), f, indent=2, default=str)

    all_variants = []

    for seed in seed_sets:
        df_seed = run_for_seed_set(seed, run_cfg)
        all_variants.append(df_seed)

    all_df = pd.concat(all_variants, ignore_index=True)

    # Save aggregated variants with scores for this run
    all_csv = run_cfg.out_dir / "all_variants_with_scores.csv"
    all_df.to_csv(all_csv, index=False)
    print(f"[{run_cfg.name}] Saved all variant scores → {all_csv}")

    # Per-seed summary: novelty percentage & binding capacity stats
    summary = (
        all_df
        .groupby("seed_set")
        .agg(
            n_variants=("sequence", "count"),
            novelty_pct=("is_novel", lambda x: 100.0 * x.mean()),
            mean_binding_capacity=("binding_capacity", "mean"),
            max_binding_capacity=("binding_capacity", "max"),
        )
        .reset_index()
    )

    summary_csv = run_cfg.out_dir / "summary_by_seed.csv"
    summary.to_csv(summary_csv, index=False)
    print(f"[{run_cfg.name}] Saved summary by seed set → {summary_csv}")

    print(f"[{run_cfg.name}] DONE.")


# ============================================================
# ABLATION ANALYSIS – COMPARING MULTIPLE RUNS
# ============================================================

def load_run_summary(run_dir: Path) -> pd.DataFrame:
    summary_path = run_dir / "summary_by_seed.csv"
    if not summary_path.exists():
        raise FileNotFoundError(f"Summary file not found: {summary_path}")
    df = pd.read_csv(summary_path)
    df["run_dir"] = str(run_dir)
    df["run_name"] = run_dir.name
    return df


def compare_runs(run_dirs: List[Path]) -> pd.DataFrame:
    """
    Load summaries from multiple runs and return combined dataframe.
    You can then plot novelty vs binding capacity for ablation analysis.
    """
    all_summaries = [load_run_summary(rd) for rd in run_dirs]
    combined = pd.concat(all_summaries, ignore_index=True)

    # Example quick plots (per run):
    plt.figure()
    for run_name, sub in combined.groupby("run_name"):
        plt.scatter(
            sub["novelty_pct"],
            sub["mean_binding_capacity"],
            label=run_name,
        )
    plt.xlabel("Novelty % (< threshold identity)")
    plt.ylabel("Mean binding capacity")
    plt.title("Run comparison: novelty vs binding capacity")
    plt.legend()
    plt.tight_layout()
    plt.show()

    return combined


# ============================================================
# EXAMPLE USAGE (EDIT FOR YOUR PROJECT)
# ============================================================

if __name__ == "__main__":
    # 1) Define all your seed FASTA files once.
    seed_sets = [
        SeedSet(
            name="pb_mer_operon",
            fasta_path=Path("PepMLM_seeds/Metal_specific/pb_seeds.fasta"),
        ),
        SeedSet(
            name="hg_specific",
            fasta_path=Path("PepMLM_seeds/Metal_specific/hg_seeds.fasta"),
        ),
        SeedSet(
            name="cd_specific",
            fasta_path=Path("PepMLM_seeds/Metal_specific/cd_seeds.fasta"),
        ),
        SeedSet(
            name="MT_bacterial_redox",
            fasta_path=Path("PepMLM_seeds/MT_seeds/MT_Bacterial_Redox.fasta"),
        ),
        SeedSet(
            name="MT_bacterial_transformation",
            fasta_path=Path("PepMLM_seeds/MT_seeds/MT_Bacterial_transformation.fasta"),
        ),
    ]

    # 2) Define different runs with different hyperparameters (for ablation)
    base_params = PepMLMParams(
        n_variants_per_seed=20,
        fraction_mask=0.10,   # fewer positions masked → more conservative
        topk_per_mask=5,      # or whatever you want to test
        max_len=200,
        batch_size=8,
    )

    low_mask_params = PepMLMParams(
        n_variants_per_seed=20,
        fraction_mask=0.05,   # fewer positions masked → more conservative
        topk_per_mask=5,      # or whatever you want to test
        max_len=200,
        batch_size=8,
    )

    high_mask_params = PepMLMParams(
        n_variants_per_seed=20,
        fraction_mask=0.25,   # fewer positions masked → more conservative
        topk_per_mask=5,      # or whatever you want to test
        max_len=200,
        batch_size=8,
    )

    runs = [
        RunConfig(
            name="run_base",
            out_dir=Path("notebook_runs/run_base"),
            pepmlm_params=base_params,
            novelty_identity_threshold=0.95,
            top_k_variants=999999,
        ),
        RunConfig(
            name="run_high_mask",
            out_dir=Path("notebook_runs/run_high_mask"),
            pepmlm_params=high_mask_params,
            novelty_identity_threshold=0.95,
            top_k_variants=999999,
        ),
        RunConfig(
            name="run_low_mask",
            out_dir=Path("notebook_runs/run_low_mask"),
            pepmlm_params=low_mask_params,
            novelty_identity_threshold=0.95,
            top_k_variants=999999,
        ),
    ]

    # 3) Run all experiments (all seed sets for each hyperparameter configuration)
    for cfg in runs:
        run_experiment(seed_sets, cfg)

    # 4) After all runs complete, do ablation analysis
    combined_summary = compare_runs([r.out_dir for r in runs])
    print(combined_summary)
# Out:
# ======================================================================
# Running experiment: run_base
# ======================================================================
# [run_base] Running PepMLM for seed set 'pb_mer_operon'
# [21:18:22] loading PepMLM model/tokenizer…
# [21:18:24] device: cpu; threads: 4
# [21:18:24] seed sp_P38990_SAK1_YEAST (len 1142) …
# [21:18:24] skip sp_P38990_SAK1_YEAST: length 1142 > MAX_LEN 200
# [21:18:24] seed sp_P04034_LDH1_LACLC (len 325) …
# [21:18:24] skip sp_P04034_LDH1_LACLC: length 325 > MAX_LEN 200
# [21:18:24] seed sp_P04140_MERT_PSEAI (len 116) …
# [21:18:48] seed sp_P25224_MATRX_RABVN (len 202) …
# [21:18:48] skip sp_P25224_MATRX_RABVN: length 202 > MAX_LEN 200
# [21:18:48] seed sp_Q9ZDL2_DHAS_RICPR (len 338) …
# [21:18:48] skip sp_Q9ZDL2_DHAS_RICPR: length 338 > MAX_LEN 200
# [21:18:48] seed tr_Q7MGP3_Q7MGP3_VIBVY (len 625) …
# [21:18:48] skip tr_Q7MGP3_Q7MGP3_VIBVY: length 625 > MAX_LEN 200
# [21:18:48] seed sp_P81803_TTF17_HADVE (len 68) …
# [21:18:54] seed tr_Q9LT07_Q9LT07_ARATH (len 175) …
# [21:19:09] seed tr_Q9ZDL3_Q9ZDL3_RICPR (len 583) …
# [21:19:09] skip tr_Q9ZDL3_Q9ZDL3_RICPR: length 583 > MAX_LEN 200
# [21:19:09] seed tr_Q9ZXN7_Q9ZXN7_9RODE (len 134) …
# [21:19:20] seed tr_Q5EJ44_Q5EJ44_HV1 (len 207) …
# [21:19:20] skip tr_Q5EJ44_Q5EJ44_HV1: length 207 > MAX_LEN 200
# [21:19:20] seed tr_Q5SL27_Q5SL27_THET8 (len 343) …
# [21:19:20] skip tr_Q5SL27_Q5SL27_THET8: length 343 > MAX_LEN 200
# [21:19:20] seed tr_Q7MFM3_Q7MFM3_VIBVY (len 128) …
# [21:19:31] seed tr_Q97L94_Q97L94_CLOAB (len 406) …
# [21:19:31] skip tr_Q97L94_Q97L94_CLOAB: length 406 > MAX_LEN 200
# [21:19:31] seed tr_Q9I2X5_Q9I2X5_PSEAE (len 532) …
# [21:19:31] skip tr_Q9I2X5_Q9I2X5_PSEAE: length 532 > MAX_LEN 200
# [21:19:31] seed tr_Q9KCH2_Q9KCH2_HALH5 (len 369) …
# [21:19:31] skip tr_Q9KCH2_Q9KCH2_HALH5: length 369 > MAX_LEN 200
# [21:19:31] seed tr_Q9RFJ9_Q9RFJ9_ACTPL (len 130) …
# [21:19:42] done: wrote 120 variants from 17 seeds → notebook_runs/run_base/seed_pb_mer_operon/generated_variants.fasta
# Seed set to 42
# Seed set to 42
# [run_base] Running MetaLATTE for seed set 'pb_mer_operon'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_base/seed_pb_mer_operon/metalatte_predictions.csv
# [run_base] Computing novelty vs seeds for 'pb_mer_operon' (threshold: 0.95)
# [run_base] Saved similarity histogram → notebook_runs/run_base/plots/identity_hist_pb_mer_operon.png
# [run_base] Running PepMLM for seed set 'hg_specific'
# [21:23:13] loading PepMLM model/tokenizer…
# [21:23:14] device: cpu; threads: 4
# [21:23:14] seed sp_D9J041_MERA_LYSSH (len 546) …
# [21:23:14] skip sp_D9J041_MERA_LYSSH: length 546 > MAX_LEN 200
# [21:23:14] seed sp_P00392_MERA_PSEAI (len 561) …
# [21:23:14] skip sp_P00392_MERA_PSEAI: length 561 > MAX_LEN 200
# [21:23:14] seed sp_P04140_MERT_PSEAI (len 116) …
# [21:23:24] seed sp_P16171_MERA_BACCE (len 631) …
# [21:23:24] skip sp_P16171_MERA_BACCE: length 631 > MAX_LEN 200
# [21:23:24] seed sp_P04131_MERP_PSEAI (len 91) …
# [21:23:32] seed sp_P08332_MERA_SHIFL (len 564) …
# [21:23:32] skip sp_P08332_MERA_SHIFL: length 564 > MAX_LEN 200
# [21:23:32] seed sp_P08662_MERA_SERMA (len 460) …
# [21:23:32] skip sp_P08662_MERA_SERMA: length 460 > MAX_LEN 200
# [21:23:32] seed sp_P0A0E4_MERA_STAES (len 547) …
# [21:23:32] skip sp_P0A0E4_MERA_STAES: length 547 > MAX_LEN 200
# [21:23:32] seed sp_P0A0E5_MERA_STAAU (len 547) …
# [21:23:32] skip sp_P0A0E5_MERA_STAAU: length 547 > MAX_LEN 200
# [21:23:32] seed sp_P17239_MERA_ACIFR (len 547) …
# [21:23:32] skip sp_P17239_MERA_ACIFR: length 547 > MAX_LEN 200
# [21:23:32] seed sp_P30341_MERA_STRLI (len 474) …
# [21:23:32] skip sp_P30341_MERA_STRLI: length 474 > MAX_LEN 200
# [21:23:32] seed sp_P94188_MERA_ALCSP (len 559) …
# [21:23:32] skip sp_P94188_MERA_ALCSP: length 559 > MAX_LEN 200
# [21:23:32] seed sp_P94702_MERA_ENTAG (len 561) …
# [21:23:32] skip sp_P94702_MERA_ENTAG: length 561 > MAX_LEN 200
# [21:23:32] seed sp_Q51772_MERA_PSEFL (len 548) …
# [21:23:32] skip sp_Q51772_MERA_PSEFL: length 548 > MAX_LEN 200
# [21:23:32] seed sp_Q52109_MERA_ACICA (len 561) …
# [21:23:32] skip sp_Q52109_MERA_ACICA: length 561 > MAX_LEN 200
# [21:23:32] seed sp_Q54465_MERA_SHEPU (len 557) …
# [21:23:32] skip sp_Q54465_MERA_SHEPU: length 557 > MAX_LEN 200
# [21:23:32] seed tr_E3HKP0_E3HKP0_ACHXA (len 95) …
# [21:23:41] seed sp_P94700_MERT_ENTAG (len 126) …
# [21:23:51] seed sp_Q54462_MERT_SHEPU (len 115) …
# [21:24:01] seed tr_Q6UP70_Q6UP70_CUPPJ (len 91) …
# [21:24:09] done: wrote 120 variants from 20 seeds → notebook_runs/run_base/seed_hg_specific/generated_variants.fasta
# Seed set to 42
# [run_base] Running MetaLATTE for seed set 'hg_specific'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_base/seed_hg_specific/metalatte_predictions.csv
# [run_base] Computing novelty vs seeds for 'hg_specific' (threshold: 0.95)
# [run_base] Saved similarity histogram → notebook_runs/run_base/plots/identity_hist_hg_specific.png
# [run_base] Running PepMLM for seed set 'cd_specific'
# [21:26:47] loading PepMLM model/tokenizer…
# [21:26:49] device: cpu; threads: 4
# [21:26:49] seed sp_P02802_MT1_MOUSE (len 61) …
# [21:26:55] seed sp_P04731_MT1A_HUMAN (len 61) …
# [21:27:00] seed sp_P27635_RL10_HUMAN (len 214) …
# [21:27:00] skip sp_P27635_RL10_HUMAN: length 214 > MAX_LEN 200
# [21:27:00] seed sp_P29274_AA2AR_HUMAN (len 412) …
# [21:27:00] skip sp_P29274_AA2AR_HUMAN: length 412 > MAX_LEN 200
# [21:27:00] seed sp_P63168_DYL1_MOUSE (len 89) …
# [21:27:08] seed sp_P80297_MT1X_HUMAN (len 61) …
# [21:27:14] seed sp_Q9TXQ1_TNKS1_CAEEL (len 2276) …
# [21:27:14] skip sp_Q9TXQ1_TNKS1_CAEEL: length 2276 > MAX_LEN 200
# [21:27:14] seed sp_P25167_RPC2_DROME (len 1137) …
# [21:27:14] skip sp_P25167_RPC2_DROME: length 1137 > MAX_LEN 200
# [21:27:14] seed sp_P37470_PTH_BACSU (len 188) …
# [21:27:29] seed sp_P50133_PTH1R_PIG (len 585) …
# [21:27:29] skip sp_P50133_PTH1R_PIG: length 585 > MAX_LEN 200
# [21:27:29] seed sp_P04204_EXE2_HELSU (len 84) …
# [21:27:36] seed sp_P41044_CAB32_DROME (len 310) …
# [21:27:36] skip sp_P41044_CAB32_DROME: length 310 > MAX_LEN 200
# [21:27:36] seed sp_Q9N0B5_TM266_MACFA (len 531) …
# [21:27:36] skip sp_Q9N0B5_TM266_MACFA: length 531 > MAX_LEN 200
# [21:27:36] seed tr_Q9XBI9_Q9XBI9_BACCE (len 307) …
# [21:27:36] skip tr_Q9XBI9_Q9XBI9_BACCE: length 307 > MAX_LEN 200
# [21:27:36] seed tr_Q7M9F1_Q7M9F1_WOLSU (len 244) …
# [21:27:36] skip tr_Q7M9F1_Q7M9F1_WOLSU: length 244 > MAX_LEN 200
# [21:27:36] seed tr_Q9Y072_Q9Y072_LAMPL (len 90) …
# [21:27:44] seed tr_Q8UUG4_Q8UUG4_ALV (len 43) …
# [21:27:49] seed tr_Q9KPX7_Q9KPX7_VIBCH (len 245) …
# [21:27:49] skip tr_Q9KPX7_Q9KPX7_VIBCH: length 245 > MAX_LEN 200
# [21:27:49] seed tr_Q9ZC39_Q9ZC39_YERPE (len 294) …
# [21:27:49] skip tr_Q9ZC39_Q9ZC39_YERPE: length 294 > MAX_LEN 200
# [21:27:49] done: wrote 160 variants from 19 seeds → notebook_runs/run_base/seed_cd_specific/generated_variants.fasta
# Seed set to 42
# [run_base] Running MetaLATTE for seed set 'cd_specific'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_base/seed_cd_specific/metalatte_predictions.csv
# [run_base] Computing novelty vs seeds for 'cd_specific' (threshold: 0.95)
# [run_base] Saved similarity histogram → notebook_runs/run_base/plots/identity_hist_cd_specific.png
# [run_base] Running PepMLM for seed set 'MT_bacterial_redox'
# [21:30:55] loading PepMLM model/tokenizer…
# [21:30:56] device: cpu; threads: 4
# [21:30:56] seed sp_P06616_ERA_ECOLI (len 301) …
# [21:30:56] skip sp_P06616_ERA_ECOLI: length 301 > MAX_LEN 200
# [21:30:56] seed sp_P07228_ITB1_CHICK (len 803) …
# [21:30:56] skip sp_P07228_ITB1_CHICK: length 803 > MAX_LEN 200
# [21:30:56] seed sp_P0A6Y8_DNAK_ECOLI (len 638) …
# [21:30:56] skip sp_P0A6Y8_DNAK_ECOLI: length 638 > MAX_LEN 200
# [21:30:56] seed sp_P0A9D8_DAPD_ECOLI (len 274) …
# [21:30:56] skip sp_P0A9D8_DAPD_ECOLI: length 274 > MAX_LEN 200
# [21:30:56] seed sp_P0AA25_THIO_ECOLI (len 109) …
# [21:31:05] seed sp_P14907_NSP1_YEAST (len 823) …
# [21:31:05] skip sp_P14907_NSP1_YEAST: length 823 > MAX_LEN 200
# [21:31:05] seed sp_P22803_TRX2_YEAST (len 104) …
# [21:31:14] seed sp_P30015_LHR_ECOLI (len 1538) …
# [21:31:14] skip sp_P30015_LHR_ECOLI: length 1538 > MAX_LEN 200
# [21:31:14] seed sp_Q9HWK6_LYSC_PSEAE (len 462) …
# [21:31:14] skip sp_Q9HWK6_LYSC_PSEAE: length 462 > MAX_LEN 200
# [21:31:14] seed sp_P27241_WAAZ_ECOLI (len 283) …
# [21:31:14] skip sp_P27241_WAAZ_ECOLI: length 283 > MAX_LEN 200
# [21:31:14] seed sp_P00255_FER_PARLV (len 97) …
# [21:31:22] seed sp_P00260_HIP_ALLVD (len 122) …
# [21:31:33] seed sp_Q8EJ54_ASTD_SHEON (len 487) …
# [21:31:33] skip sp_Q8EJ54_ASTD_SHEON: length 487 > MAX_LEN 200
# [21:31:33] seed sp_P10582_DPOM_MAIZE (len 929) …
# [21:31:33] skip sp_P10582_DPOM_MAIZE: length 929 > MAX_LEN 200
# [21:31:33] seed tr_Q8EJ52_Q8EJ52_SHEON (len 442) …
# [21:31:33] skip tr_Q8EJ52_Q8EJ52_SHEON: length 442 > MAX_LEN 200
# [21:31:33] seed tr_Q9HXJ0_Q9HXJ0_PSEAE (len 107) …
# [21:31:42] seed tr_Q9KXJ2_Q9KXJ2_STRCO (len 218) …
# [21:31:42] skip tr_Q9KXJ2_Q9KXJ2_STRCO: length 218 > MAX_LEN 200
# [21:31:42] seed tr_Q9I2X5_Q9I2X5_PSEAE (len 532) …
# [21:31:42] skip tr_Q9I2X5_Q9I2X5_PSEAE: length 532 > MAX_LEN 200
# [21:31:42] seed tr_Q9KQE2_Q9KQE2_VIBCH (len 167) …
# [21:31:56] seed tr_Q9ZEV9_Q9ZEV9_KLUIN (len 251) …
# [21:31:56] skip tr_Q9ZEV9_Q9ZEV9_KLUIN: length 251 > MAX_LEN 200
# [21:31:56] done: wrote 120 variants from 20 seeds → notebook_runs/run_base/seed_MT_bacterial_redox/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_base] Running MetaLATTE for seed set 'MT_bacterial_redox'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_base/seed_MT_bacterial_redox/metalatte_predictions.csv
# [run_base] Computing novelty vs seeds for 'MT_bacterial_redox' (threshold: 0.95)
# [run_base] Saved similarity histogram → notebook_runs/run_base/plots/identity_hist_MT_bacterial_redox.png
# [run_base] Running PepMLM for seed set 'MT_bacterial_transformation'
# [21:34:43] loading PepMLM model/tokenizer…
# [21:34:43] device: cpu; threads: 4
# [21:34:43] seed sp_P0CS90_HSP77_YEAST (len 654) …
# [21:34:43] skip sp_P0CS90_HSP77_YEAST: length 654 > MAX_LEN 200
# [21:34:43] seed sp_P0CS91_HSP77_YEASX (len 655) …
# [21:34:43] skip sp_P0CS91_HSP77_YEASX: length 655 > MAX_LEN 200
# [21:34:43] seed sp_P27635_RL10_HUMAN (len 214) …
# [21:34:43] skip sp_P27635_RL10_HUMAN: length 214 > MAX_LEN 200
# [21:34:43] seed sp_Q99383_HRP1_YEAST (len 534) …
# [21:34:43] skip sp_Q99383_HRP1_YEAST: length 534 > MAX_LEN 200
# [21:34:43] seed sp_Q9TXQ1_TNKS1_CAEEL (len 2276) …
# [21:34:43] skip sp_Q9TXQ1_TNKS1_CAEEL: length 2276 > MAX_LEN 200
# [21:34:43] seed sp_Q9ZKJ5_CTKA_HELPJ (len 325) …
# [21:34:43] skip sp_Q9ZKJ5_CTKA_HELPJ: length 325 > MAX_LEN 200
# [21:34:43] seed sp_O74361_CBP7_SCHPO (len 356) …
# [21:34:43] skip sp_O74361_CBP7_SCHPO: length 356 > MAX_LEN 200
# [21:34:43] seed sp_P50133_PTH1R_PIG (len 585) …
# [21:34:43] skip sp_P50133_PTH1R_PIG: length 585 > MAX_LEN 200
# [21:34:43] seed tr_Q39687_Q39687_DAUCA (len 577) …
# [21:34:43] skip tr_Q39687_Q39687_DAUCA: length 577 > MAX_LEN 200
# [21:34:43] seed sp_Q9N0B5_TM266_MACFA (len 531) …
# [21:34:43] skip sp_Q9N0B5_TM266_MACFA: length 531 > MAX_LEN 200
# [21:34:43] seed tr_Q9S7Z4_Q9S7Z4_MARPO (len 548) …
# [21:34:43] skip tr_Q9S7Z4_Q9S7Z4_MARPO: length 548 > MAX_LEN 200
# [21:34:43] seed tr_Q07958_Q07958_HV1 (len 98) …
# [21:34:52] seed tr_Q8KQ19_Q8KQ19_PSEAI (len 461) …
# [21:34:52] skip tr_Q8KQ19_Q8KQ19_PSEAI: length 461 > MAX_LEN 200
# [21:34:52] seed tr_Q8UUG4_Q8UUG4_ALV (len 43) …
# [21:34:56] seed tr_Q9HZY1_Q9HZY1_PSEAE (len 476) …
# [21:34:56] skip tr_Q9HZY1_Q9HZY1_PSEAE: length 476 > MAX_LEN 200
# [21:34:56] done: wrote 40 variants from 15 seeds → notebook_runs/run_base/seed_MT_bacterial_transformation/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_base] Running MetaLATTE for seed set 'MT_bacterial_transformation'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_base/seed_MT_bacterial_transformation/metalatte_predictions.csv
# [run_base] Computing novelty vs seeds for 'MT_bacterial_transformation' (threshold: 0.95)
# [run_base] Saved similarity histogram → notebook_runs/run_base/plots/identity_hist_MT_bacterial_transformation.png
# [run_base] Saved all variant scores → notebook_runs/run_base/all_variants_with_scores.csv
# [run_base] Saved summary by seed set → notebook_runs/run_base/summary_by_seed.csv
# [run_base] DONE.
# ======================================================================
# Running experiment: run_high_mask
# ======================================================================
# [run_high_mask] Running PepMLM for seed set 'pb_mer_operon'
# [21:35:53] loading PepMLM model/tokenizer…
# [21:35:53] device: cpu; threads: 4
# [21:35:53] seed sp_P38990_SAK1_YEAST (len 1142) …
# [21:35:53] skip sp_P38990_SAK1_YEAST: length 1142 > MAX_LEN 200
# [21:35:53] seed sp_P04034_LDH1_LACLC (len 325) …
# [21:35:53] skip sp_P04034_LDH1_LACLC: length 325 > MAX_LEN 200
# [21:35:53] seed sp_P04140_MERT_PSEAI (len 116) …
# [21:36:03] seed sp_P25224_MATRX_RABVN (len 202) …
# [21:36:03] skip sp_P25224_MATRX_RABVN: length 202 > MAX_LEN 200
# [21:36:03] seed sp_Q9ZDL2_DHAS_RICPR (len 338) …
# [21:36:03] skip sp_Q9ZDL2_DHAS_RICPR: length 338 > MAX_LEN 200
# [21:36:03] seed tr_Q7MGP3_Q7MGP3_VIBVY (len 625) …
# [21:36:03] skip tr_Q7MGP3_Q7MGP3_VIBVY: length 625 > MAX_LEN 200
# [21:36:03] seed sp_P81803_TTF17_HADVE (len 68) …
# [21:36:10] seed tr_Q9LT07_Q9LT07_ARATH (len 175) …
# [21:36:25] seed tr_Q9ZDL3_Q9ZDL3_RICPR (len 583) …
# [21:36:25] skip tr_Q9ZDL3_Q9ZDL3_RICPR: length 583 > MAX_LEN 200
# [21:36:25] seed tr_Q9ZXN7_Q9ZXN7_9RODE (len 134) …
# [21:36:38] seed tr_Q5EJ44_Q5EJ44_HV1 (len 207) …
# [21:36:38] skip tr_Q5EJ44_Q5EJ44_HV1: length 207 > MAX_LEN 200
# [21:36:38] seed tr_Q5SL27_Q5SL27_THET8 (len 343) …
# [21:36:38] skip tr_Q5SL27_Q5SL27_THET8: length 343 > MAX_LEN 200
# [21:36:38] seed tr_Q7MFM3_Q7MFM3_VIBVY (len 128) …
# [21:36:49] seed tr_Q97L94_Q97L94_CLOAB (len 406) …
# [21:36:49] skip tr_Q97L94_Q97L94_CLOAB: length 406 > MAX_LEN 200
# [21:36:49] seed tr_Q9I2X5_Q9I2X5_PSEAE (len 532) …
# [21:36:49] skip tr_Q9I2X5_Q9I2X5_PSEAE: length 532 > MAX_LEN 200
# [21:36:49] seed tr_Q9KCH2_Q9KCH2_HALH5 (len 369) …
# [21:36:49] skip tr_Q9KCH2_Q9KCH2_HALH5: length 369 > MAX_LEN 200
# [21:36:49] seed tr_Q9RFJ9_Q9RFJ9_ACTPL (len 130) …
# [21:36:59] done: wrote 120 variants from 17 seeds → notebook_runs/run_high_mask/seed_pb_mer_operon/generated_variants.fasta
# Seed set to 42
# [run_high_mask] Running MetaLATTE for seed set 'pb_mer_operon'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_high_mask/seed_pb_mer_operon/metalatte_predictions.csv
# [run_high_mask] Computing novelty vs seeds for 'pb_mer_operon' (threshold: 0.95)
# [run_high_mask] Saved similarity histogram → notebook_runs/run_high_mask/plots/identity_hist_pb_mer_operon.png
# [run_high_mask] Running PepMLM for seed set 'hg_specific'
# [21:39:57] loading PepMLM model/tokenizer…
# [21:39:57] device: cpu; threads: 4
# [21:39:57] seed sp_D9J041_MERA_LYSSH (len 546) …
# [21:39:57] skip sp_D9J041_MERA_LYSSH: length 546 > MAX_LEN 200
# [21:39:57] seed sp_P00392_MERA_PSEAI (len 561) …
# [21:39:57] skip sp_P00392_MERA_PSEAI: length 561 > MAX_LEN 200
# [21:39:57] seed sp_P04140_MERT_PSEAI (len 116) …
# [21:40:08] seed sp_P16171_MERA_BACCE (len 631) …
# [21:40:08] skip sp_P16171_MERA_BACCE: length 631 > MAX_LEN 200
# [21:40:08] seed sp_P04131_MERP_PSEAI (len 91) …
# [21:40:16] seed sp_P08332_MERA_SHIFL (len 564) …
# [21:40:16] skip sp_P08332_MERA_SHIFL: length 564 > MAX_LEN 200
# [21:40:16] seed sp_P08662_MERA_SERMA (len 460) …
# [21:40:16] skip sp_P08662_MERA_SERMA: length 460 > MAX_LEN 200
# [21:40:16] seed sp_P0A0E4_MERA_STAES (len 547) …
# [21:40:16] skip sp_P0A0E4_MERA_STAES: length 547 > MAX_LEN 200
# [21:40:16] seed sp_P0A0E5_MERA_STAAU (len 547) …
# [21:40:16] skip sp_P0A0E5_MERA_STAAU: length 547 > MAX_LEN 200
# [21:40:16] seed sp_P17239_MERA_ACIFR (len 547) …
# [21:40:16] skip sp_P17239_MERA_ACIFR: length 547 > MAX_LEN 200
# [21:40:16] seed sp_P30341_MERA_STRLI (len 474) …
# [21:40:16] skip sp_P30341_MERA_STRLI: length 474 > MAX_LEN 200
# [21:40:16] seed sp_P94188_MERA_ALCSP (len 559) …
# [21:40:16] skip sp_P94188_MERA_ALCSP: length 559 > MAX_LEN 200
# [21:40:16] seed sp_P94702_MERA_ENTAG (len 561) …
# [21:40:16] skip sp_P94702_MERA_ENTAG: length 561 > MAX_LEN 200
# [21:40:16] seed sp_Q51772_MERA_PSEFL (len 548) …
# [21:40:16] skip sp_Q51772_MERA_PSEFL: length 548 > MAX_LEN 200
# [21:40:16] seed sp_Q52109_MERA_ACICA (len 561) …
# [21:40:16] skip sp_Q52109_MERA_ACICA: length 561 > MAX_LEN 200
# [21:40:16] seed sp_Q54465_MERA_SHEPU (len 557) …
# [21:40:16] skip sp_Q54465_MERA_SHEPU: length 557 > MAX_LEN 200
# [21:40:16] seed tr_E3HKP0_E3HKP0_ACHXA (len 95) …
# [21:40:25] seed sp_P94700_MERT_ENTAG (len 126) …
# [21:40:35] seed sp_Q54462_MERT_SHEPU (len 115) …
# [21:40:45] seed tr_Q6UP70_Q6UP70_CUPPJ (len 91) …
# [21:40:56] done: wrote 120 variants from 20 seeds → notebook_runs/run_high_mask/seed_hg_specific/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_high_mask] Running MetaLATTE for seed set 'hg_specific'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_high_mask/seed_hg_specific/metalatte_predictions.csv
# [run_high_mask] Computing novelty vs seeds for 'hg_specific' (threshold: 0.95)
# [run_high_mask] Saved similarity histogram → notebook_runs/run_high_mask/plots/identity_hist_hg_specific.png
# [run_high_mask] Running PepMLM for seed set 'cd_specific'
# [21:43:42] loading PepMLM model/tokenizer…
# [21:43:44] device: cpu; threads: 4
# [21:43:44] seed sp_P02802_MT1_MOUSE (len 61) …
# [21:43:50] seed sp_P04731_MT1A_HUMAN (len 61) …
# [21:43:56] seed sp_P27635_RL10_HUMAN (len 214) …
# [21:43:56] skip sp_P27635_RL10_HUMAN: length 214 > MAX_LEN 200
# [21:43:56] seed sp_P29274_AA2AR_HUMAN (len 412) …
# [21:43:56] skip sp_P29274_AA2AR_HUMAN: length 412 > MAX_LEN 200
# [21:43:56] seed sp_P63168_DYL1_MOUSE (len 89) …
# [21:44:04] seed sp_P80297_MT1X_HUMAN (len 61) …
# [21:44:10] seed sp_Q9TXQ1_TNKS1_CAEEL (len 2276) …
# [21:44:10] skip sp_Q9TXQ1_TNKS1_CAEEL: length 2276 > MAX_LEN 200
# [21:44:10] seed sp_P25167_RPC2_DROME (len 1137) …
# [21:44:10] skip sp_P25167_RPC2_DROME: length 1137 > MAX_LEN 200
# [21:44:10] seed sp_P37470_PTH_BACSU (len 188) …
# [21:44:26] seed sp_P50133_PTH1R_PIG (len 585) …
# [21:44:26] skip sp_P50133_PTH1R_PIG: length 585 > MAX_LEN 200
# [21:44:26] seed sp_P04204_EXE2_HELSU (len 84) …
# [21:44:33] seed sp_P41044_CAB32_DROME (len 310) …
# [21:44:33] skip sp_P41044_CAB32_DROME: length 310 > MAX_LEN 200
# [21:44:33] seed sp_Q9N0B5_TM266_MACFA (len 531) …
# [21:44:33] skip sp_Q9N0B5_TM266_MACFA: length 531 > MAX_LEN 200
# [21:44:33] seed tr_Q9XBI9_Q9XBI9_BACCE (len 307) …
# [21:44:33] skip tr_Q9XBI9_Q9XBI9_BACCE: length 307 > MAX_LEN 200
# [21:44:33] seed tr_Q7M9F1_Q7M9F1_WOLSU (len 244) …
# [21:44:33] skip tr_Q7M9F1_Q7M9F1_WOLSU: length 244 > MAX_LEN 200
# [21:44:33] seed tr_Q9Y072_Q9Y072_LAMPL (len 90) …
# [21:44:41] seed tr_Q8UUG4_Q8UUG4_ALV (len 43) …
# [21:44:45] seed tr_Q9KPX7_Q9KPX7_VIBCH (len 245) …
# [21:44:45] skip tr_Q9KPX7_Q9KPX7_VIBCH: length 245 > MAX_LEN 200
# [21:44:45] seed tr_Q9ZC39_Q9ZC39_YERPE (len 294) …
# [21:44:45] skip tr_Q9ZC39_Q9ZC39_YERPE: length 294 > MAX_LEN 200
# [21:44:45] done: wrote 160 variants from 19 seeds → notebook_runs/run_high_mask/seed_cd_specific/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_high_mask] Running MetaLATTE for seed set 'cd_specific'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_high_mask/seed_cd_specific/metalatte_predictions.csv
# [run_high_mask] Computing novelty vs seeds for 'cd_specific' (threshold: 0.95)
# [run_high_mask] Saved similarity histogram → notebook_runs/run_high_mask/plots/identity_hist_cd_specific.png
# [run_high_mask] Running PepMLM for seed set 'MT_bacterial_redox'
# [21:47:45] loading PepMLM model/tokenizer…
# [21:47:48] device: cpu; threads: 4
# [21:47:48] seed sp_P06616_ERA_ECOLI (len 301) …
# [21:47:48] skip sp_P06616_ERA_ECOLI: length 301 > MAX_LEN 200
# [21:47:48] seed sp_P07228_ITB1_CHICK (len 803) …
# [21:47:48] skip sp_P07228_ITB1_CHICK: length 803 > MAX_LEN 200
# [21:47:48] seed sp_P0A6Y8_DNAK_ECOLI (len 638) …
# [21:47:48] skip sp_P0A6Y8_DNAK_ECOLI: length 638 > MAX_LEN 200
# [21:47:48] seed sp_P0A9D8_DAPD_ECOLI (len 274) …
# [21:47:48] skip sp_P0A9D8_DAPD_ECOLI: length 274 > MAX_LEN 200
# [21:47:48] seed sp_P0AA25_THIO_ECOLI (len 109) …
# [21:47:57] seed sp_P14907_NSP1_YEAST (len 823) …
# [21:47:57] skip sp_P14907_NSP1_YEAST: length 823 > MAX_LEN 200
# [21:47:57] seed sp_P22803_TRX2_YEAST (len 104) …
# [21:48:07] seed sp_P30015_LHR_ECOLI (len 1538) …
# [21:48:07] skip sp_P30015_LHR_ECOLI: length 1538 > MAX_LEN 200
# [21:48:07] seed sp_Q9HWK6_LYSC_PSEAE (len 462) …
# [21:48:07] skip sp_Q9HWK6_LYSC_PSEAE: length 462 > MAX_LEN 200
# [21:48:07] seed sp_P27241_WAAZ_ECOLI (len 283) …
# [21:48:07] skip sp_P27241_WAAZ_ECOLI: length 283 > MAX_LEN 200
# [21:48:07] seed sp_P00255_FER_PARLV (len 97) …
# [21:48:19] seed sp_P00260_HIP_ALLVD (len 122) …
# [21:48:41] seed sp_Q8EJ54_ASTD_SHEON (len 487) …
# [21:48:41] skip sp_Q8EJ54_ASTD_SHEON: length 487 > MAX_LEN 200
# [21:48:41] seed sp_P10582_DPOM_MAIZE (len 929) …
# [21:48:41] skip sp_P10582_DPOM_MAIZE: length 929 > MAX_LEN 200
# [21:48:41] seed tr_Q8EJ52_Q8EJ52_SHEON (len 442) …
# [21:48:41] skip tr_Q8EJ52_Q8EJ52_SHEON: length 442 > MAX_LEN 200
# [21:48:41] seed tr_Q9HXJ0_Q9HXJ0_PSEAE (len 107) …
# [21:48:55] seed tr_Q9KXJ2_Q9KXJ2_STRCO (len 218) …
# [21:48:55] skip tr_Q9KXJ2_Q9KXJ2_STRCO: length 218 > MAX_LEN 200
# [21:48:55] seed tr_Q9I2X5_Q9I2X5_PSEAE (len 532) …
# [21:48:55] skip tr_Q9I2X5_Q9I2X5_PSEAE: length 532 > MAX_LEN 200
# [21:48:55] seed tr_Q9KQE2_Q9KQE2_VIBCH (len 167) …
# [21:49:09] seed tr_Q9ZEV9_Q9ZEV9_KLUIN (len 251) …
# [21:49:09] skip tr_Q9ZEV9_Q9ZEV9_KLUIN: length 251 > MAX_LEN 200
# [21:49:09] done: wrote 120 variants from 20 seeds → notebook_runs/run_high_mask/seed_MT_bacterial_redox/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_high_mask] Running MetaLATTE for seed set 'MT_bacterial_redox'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_high_mask/seed_MT_bacterial_redox/metalatte_predictions.csv
# [run_high_mask] Computing novelty vs seeds for 'MT_bacterial_redox' (threshold: 0.95)
# [run_high_mask] Saved similarity histogram → notebook_runs/run_high_mask/plots/identity_hist_MT_bacterial_redox.png
# [run_high_mask] Running PepMLM for seed set 'MT_bacterial_transformation'
# [21:51:59] loading PepMLM model/tokenizer…
# [21:51:59] device: cpu; threads: 4
# [21:51:59] seed sp_P0CS90_HSP77_YEAST (len 654) …
# [21:51:59] skip sp_P0CS90_HSP77_YEAST: length 654 > MAX_LEN 200
# [21:51:59] seed sp_P0CS91_HSP77_YEASX (len 655) …
# [21:51:59] skip sp_P0CS91_HSP77_YEASX: length 655 > MAX_LEN 200
# [21:51:59] seed sp_P27635_RL10_HUMAN (len 214) …
# [21:51:59] skip sp_P27635_RL10_HUMAN: length 214 > MAX_LEN 200
# [21:51:59] seed sp_Q99383_HRP1_YEAST (len 534) …
# [21:51:59] skip sp_Q99383_HRP1_YEAST: length 534 > MAX_LEN 200
# [21:51:59] seed sp_Q9TXQ1_TNKS1_CAEEL (len 2276) …
# [21:51:59] skip sp_Q9TXQ1_TNKS1_CAEEL: length 2276 > MAX_LEN 200
# [21:51:59] seed sp_Q9ZKJ5_CTKA_HELPJ (len 325) …
# [21:51:59] skip sp_Q9ZKJ5_CTKA_HELPJ: length 325 > MAX_LEN 200
# [21:51:59] seed sp_O74361_CBP7_SCHPO (len 356) …
# [21:51:59] skip sp_O74361_CBP7_SCHPO: length 356 > MAX_LEN 200
# [21:51:59] seed sp_P50133_PTH1R_PIG (len 585) …
# [21:51:59] skip sp_P50133_PTH1R_PIG: length 585 > MAX_LEN 200
# [21:51:59] seed tr_Q39687_Q39687_DAUCA (len 577) …
# [21:51:59] skip tr_Q39687_Q39687_DAUCA: length 577 > MAX_LEN 200
# [21:51:59] seed sp_Q9N0B5_TM266_MACFA (len 531) …
# [21:51:59] skip sp_Q9N0B5_TM266_MACFA: length 531 > MAX_LEN 200
# [21:51:59] seed tr_Q9S7Z4_Q9S7Z4_MARPO (len 548) …
# [21:51:59] skip tr_Q9S7Z4_Q9S7Z4_MARPO: length 548 > MAX_LEN 200
# [21:51:59] seed tr_Q07958_Q07958_HV1 (len 98) …
# [21:52:08] seed tr_Q8KQ19_Q8KQ19_PSEAI (len 461) …
# [21:52:08] skip tr_Q8KQ19_Q8KQ19_PSEAI: length 461 > MAX_LEN 200
# [21:52:08] seed tr_Q8UUG4_Q8UUG4_ALV (len 43) …
# [21:52:12] seed tr_Q9HZY1_Q9HZY1_PSEAE (len 476) …
# [21:52:12] skip tr_Q9HZY1_Q9HZY1_PSEAE: length 476 > MAX_LEN 200
# [21:52:12] done: wrote 40 variants from 15 seeds → notebook_runs/run_high_mask/seed_MT_bacterial_transformation/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_high_mask] Running MetaLATTE for seed set 'MT_bacterial_transformation'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_high_mask/seed_MT_bacterial_transformation/metalatte_predictions.csv
# [run_high_mask] Computing novelty vs seeds for 'MT_bacterial_transformation' (threshold: 0.95)
# [run_high_mask] Saved similarity histogram → notebook_runs/run_high_mask/plots/identity_hist_MT_bacterial_transformation.png
# [run_high_mask] Saved all variant scores → notebook_runs/run_high_mask/all_variants_with_scores.csv
# [run_high_mask] Saved summary by seed set → notebook_runs/run_high_mask/summary_by_seed.csv
# [run_high_mask] DONE.
# ======================================================================
# Running experiment: run_low_mask
# ======================================================================
# [run_low_mask] Running PepMLM for seed set 'pb_mer_operon'
# [21:52:55] loading PepMLM model/tokenizer…
# [21:52:56] device: cpu; threads: 4
# [21:52:56] seed sp_P38990_SAK1_YEAST (len 1142) …
# [21:52:56] skip sp_P38990_SAK1_YEAST: length 1142 > MAX_LEN 200
# [21:52:56] seed sp_P04034_LDH1_LACLC (len 325) …
# [21:52:56] skip sp_P04034_LDH1_LACLC: length 325 > MAX_LEN 200
# [21:52:56] seed sp_P04140_MERT_PSEAI (len 116) …
# [21:53:06] seed sp_P25224_MATRX_RABVN (len 202) …
# [21:53:06] skip sp_P25224_MATRX_RABVN: length 202 > MAX_LEN 200
# [21:53:06] seed sp_Q9ZDL2_DHAS_RICPR (len 338) …
# [21:53:06] skip sp_Q9ZDL2_DHAS_RICPR: length 338 > MAX_LEN 200
# [21:53:06] seed tr_Q7MGP3_Q7MGP3_VIBVY (len 625) …
# [21:53:06] skip tr_Q7MGP3_Q7MGP3_VIBVY: length 625 > MAX_LEN 200
# [21:53:06] seed sp_P81803_TTF17_HADVE (len 68) …
# [21:53:13] seed tr_Q9LT07_Q9LT07_ARATH (len 175) …
# [21:53:28] seed tr_Q9ZDL3_Q9ZDL3_RICPR (len 583) …
# [21:53:28] skip tr_Q9ZDL3_Q9ZDL3_RICPR: length 583 > MAX_LEN 200
# [21:53:28] seed tr_Q9ZXN7_Q9ZXN7_9RODE (len 134) …
# [21:53:40] seed tr_Q5EJ44_Q5EJ44_HV1 (len 207) …
# [21:53:40] skip tr_Q5EJ44_Q5EJ44_HV1: length 207 > MAX_LEN 200
# [21:53:40] seed tr_Q5SL27_Q5SL27_THET8 (len 343) …
# [21:53:40] skip tr_Q5SL27_Q5SL27_THET8: length 343 > MAX_LEN 200
# [21:53:40] seed tr_Q7MFM3_Q7MFM3_VIBVY (len 128) …
# [21:53:51] seed tr_Q97L94_Q97L94_CLOAB (len 406) …
# [21:53:51] skip tr_Q97L94_Q97L94_CLOAB: length 406 > MAX_LEN 200
# [21:53:51] seed tr_Q9I2X5_Q9I2X5_PSEAE (len 532) …
# [21:53:51] skip tr_Q9I2X5_Q9I2X5_PSEAE: length 532 > MAX_LEN 200
# [21:53:51] seed tr_Q9KCH2_Q9KCH2_HALH5 (len 369) …
# [21:53:51] skip tr_Q9KCH2_Q9KCH2_HALH5: length 369 > MAX_LEN 200
# [21:53:51] seed tr_Q9RFJ9_Q9RFJ9_ACTPL (len 130) …
# [21:54:02] done: wrote 120 variants from 17 seeds → notebook_runs/run_low_mask/seed_pb_mer_operon/generated_variants.fasta
# Seed set to 42
# [run_low_mask] Running MetaLATTE for seed set 'pb_mer_operon'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_low_mask/seed_pb_mer_operon/metalatte_predictions.csv
# [run_low_mask] Computing novelty vs seeds for 'pb_mer_operon' (threshold: 0.95)
# [run_low_mask] Saved similarity histogram → notebook_runs/run_low_mask/plots/identity_hist_pb_mer_operon.png
# [run_low_mask] Running PepMLM for seed set 'hg_specific'
# [21:57:15] loading PepMLM model/tokenizer…
# [21:57:15] device: cpu; threads: 4
# [21:57:15] seed sp_D9J041_MERA_LYSSH (len 546) …
# [21:57:15] skip sp_D9J041_MERA_LYSSH: length 546 > MAX_LEN 200
# [21:57:15] seed sp_P00392_MERA_PSEAI (len 561) …
# [21:57:15] skip sp_P00392_MERA_PSEAI: length 561 > MAX_LEN 200
# [21:57:15] seed sp_P04140_MERT_PSEAI (len 116) …
# [21:57:26] seed sp_P16171_MERA_BACCE (len 631) …
# [21:57:26] skip sp_P16171_MERA_BACCE: length 631 > MAX_LEN 200
# [21:57:26] seed sp_P04131_MERP_PSEAI (len 91) …
# [21:57:34] seed sp_P08332_MERA_SHIFL (len 564) …
# [21:57:34] skip sp_P08332_MERA_SHIFL: length 564 > MAX_LEN 200
# [21:57:34] seed sp_P08662_MERA_SERMA (len 460) …
# [21:57:34] skip sp_P08662_MERA_SERMA: length 460 > MAX_LEN 200
# [21:57:34] seed sp_P0A0E4_MERA_STAES (len 547) …
# [21:57:34] skip sp_P0A0E4_MERA_STAES: length 547 > MAX_LEN 200
# [21:57:34] seed sp_P0A0E5_MERA_STAAU (len 547) …
# [21:57:34] skip sp_P0A0E5_MERA_STAAU: length 547 > MAX_LEN 200
# [21:57:34] seed sp_P17239_MERA_ACIFR (len 547) …
# [21:57:34] skip sp_P17239_MERA_ACIFR: length 547 > MAX_LEN 200
# [21:57:34] seed sp_P30341_MERA_STRLI (len 474) …
# [21:57:34] skip sp_P30341_MERA_STRLI: length 474 > MAX_LEN 200
# [21:57:34] seed sp_P94188_MERA_ALCSP (len 559) …
# [21:57:34] skip sp_P94188_MERA_ALCSP: length 559 > MAX_LEN 200
# [21:57:34] seed sp_P94702_MERA_ENTAG (len 561) …
# [21:57:34] skip sp_P94702_MERA_ENTAG: length 561 > MAX_LEN 200
# [21:57:34] seed sp_Q51772_MERA_PSEFL (len 548) …
# [21:57:34] skip sp_Q51772_MERA_PSEFL: length 548 > MAX_LEN 200
# [21:57:34] seed sp_Q52109_MERA_ACICA (len 561) …
# [21:57:34] skip sp_Q52109_MERA_ACICA: length 561 > MAX_LEN 200
# [21:57:34] seed sp_Q54465_MERA_SHEPU (len 557) …
# [21:57:34] skip sp_Q54465_MERA_SHEPU: length 557 > MAX_LEN 200
# [21:57:34] seed tr_E3HKP0_E3HKP0_ACHXA (len 95) …
# [21:57:42] seed sp_P94700_MERT_ENTAG (len 126) …
# [21:57:52] seed sp_Q54462_MERT_SHEPU (len 115) …
# [21:58:02] seed tr_Q6UP70_Q6UP70_CUPPJ (len 91) …
# [21:58:10] done: wrote 120 variants from 20 seeds → notebook_runs/run_low_mask/seed_hg_specific/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_low_mask] Running MetaLATTE for seed set 'hg_specific'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_low_mask/seed_hg_specific/metalatte_predictions.csv
# [run_low_mask] Computing novelty vs seeds for 'hg_specific' (threshold: 0.95)
# [run_low_mask] Saved similarity histogram → notebook_runs/run_low_mask/plots/identity_hist_hg_specific.png
# [run_low_mask] Running PepMLM for seed set 'cd_specific'
# [22:00:50] loading PepMLM model/tokenizer…
# [22:00:52] device: cpu; threads: 4
# [22:00:52] seed sp_P02802_MT1_MOUSE (len 61) …
# [22:01:02] seed sp_P04731_MT1A_HUMAN (len 61) …
# [22:01:11] seed sp_P27635_RL10_HUMAN (len 214) …
# [22:01:11] skip sp_P27635_RL10_HUMAN: length 214 > MAX_LEN 200
# [22:01:11] seed sp_P29274_AA2AR_HUMAN (len 412) …
# [22:01:11] skip sp_P29274_AA2AR_HUMAN: length 412 > MAX_LEN 200
# [22:01:11] seed sp_P63168_DYL1_MOUSE (len 89) …
# [22:01:19] seed sp_P80297_MT1X_HUMAN (len 61) …
# [22:01:25] seed sp_Q9TXQ1_TNKS1_CAEEL (len 2276) …
# [22:01:25] skip sp_Q9TXQ1_TNKS1_CAEEL: length 2276 > MAX_LEN 200
# [22:01:25] seed sp_P25167_RPC2_DROME (len 1137) …
# [22:01:25] skip sp_P25167_RPC2_DROME: length 1137 > MAX_LEN 200
# [22:01:25] seed sp_P37470_PTH_BACSU (len 188) …
# [22:01:42] seed sp_P50133_PTH1R_PIG (len 585) …
# [22:01:42] skip sp_P50133_PTH1R_PIG: length 585 > MAX_LEN 200
# [22:01:42] seed sp_P04204_EXE2_HELSU (len 84) …
# [22:01:50] seed sp_P41044_CAB32_DROME (len 310) …
# [22:01:50] skip sp_P41044_CAB32_DROME: length 310 > MAX_LEN 200
# [22:01:50] seed sp_Q9N0B5_TM266_MACFA (len 531) …
# [22:01:50] skip sp_Q9N0B5_TM266_MACFA: length 531 > MAX_LEN 200
# [22:01:50] seed tr_Q9XBI9_Q9XBI9_BACCE (len 307) …
# [22:01:50] skip tr_Q9XBI9_Q9XBI9_BACCE: length 307 > MAX_LEN 200
# [22:01:50] seed tr_Q7M9F1_Q7M9F1_WOLSU (len 244) …
# [22:01:50] skip tr_Q7M9F1_Q7M9F1_WOLSU: length 244 > MAX_LEN 200
# [22:01:50] seed tr_Q9Y072_Q9Y072_LAMPL (len 90) …
# [22:01:58] seed tr_Q8UUG4_Q8UUG4_ALV (len 43) …
# [22:02:02] seed tr_Q9KPX7_Q9KPX7_VIBCH (len 245) …
# [22:02:02] skip tr_Q9KPX7_Q9KPX7_VIBCH: length 245 > MAX_LEN 200
# [22:02:02] seed tr_Q9ZC39_Q9ZC39_YERPE (len 294) …
# [22:02:02] skip tr_Q9ZC39_Q9ZC39_YERPE: length 294 > MAX_LEN 200
# [22:02:02] done: wrote 160 variants from 19 seeds → notebook_runs/run_low_mask/seed_cd_specific/generated_variants.fasta
# Seed set to 42
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [run_low_mask] Running MetaLATTE for seed set 'cd_specific'
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_low_mask/seed_cd_specific/metalatte_predictions.csv
# [run_low_mask] Computing novelty vs seeds for 'cd_specific' (threshold: 0.95)
# [run_low_mask] Saved similarity histogram → notebook_runs/run_low_mask/plots/identity_hist_cd_specific.png
# [run_low_mask] Running PepMLM for seed set 'MT_bacterial_redox'
# [22:04:51] loading PepMLM model/tokenizer…
# [22:04:53] device: cpu; threads: 4
# [22:04:53] seed sp_P06616_ERA_ECOLI (len 301) …
# [22:04:53] skip sp_P06616_ERA_ECOLI: length 301 > MAX_LEN 200
# [22:04:53] seed sp_P07228_ITB1_CHICK (len 803) …
# [22:04:53] skip sp_P07228_ITB1_CHICK: length 803 > MAX_LEN 200
# [22:04:53] seed sp_P0A6Y8_DNAK_ECOLI (len 638) …
# [22:04:53] skip sp_P0A6Y8_DNAK_ECOLI: length 638 > MAX_LEN 200
# [22:04:53] seed sp_P0A9D8_DAPD_ECOLI (len 274) …
# [22:04:53] skip sp_P0A9D8_DAPD_ECOLI: length 274 > MAX_LEN 200
# [22:04:53] seed sp_P0AA25_THIO_ECOLI (len 109) …
# [22:05:03] seed sp_P14907_NSP1_YEAST (len 823) …
# [22:05:03] skip sp_P14907_NSP1_YEAST: length 823 > MAX_LEN 200
# [22:05:03] seed sp_P22803_TRX2_YEAST (len 104) …
# [22:05:13] seed sp_P30015_LHR_ECOLI (len 1538) …
# [22:05:13] skip sp_P30015_LHR_ECOLI: length 1538 > MAX_LEN 200
# [22:05:13] seed sp_Q9HWK6_LYSC_PSEAE (len 462) …
# [22:05:13] skip sp_Q9HWK6_LYSC_PSEAE: length 462 > MAX_LEN 200
# [22:05:13] seed sp_P27241_WAAZ_ECOLI (len 283) …
# [22:05:13] skip sp_P27241_WAAZ_ECOLI: length 283 > MAX_LEN 200
# [22:05:13] seed sp_P00255_FER_PARLV (len 97) …
# [22:05:21] seed sp_P00260_HIP_ALLVD (len 122) …
# [22:05:31] seed sp_Q8EJ54_ASTD_SHEON (len 487) …
# [22:05:31] skip sp_Q8EJ54_ASTD_SHEON: length 487 > MAX_LEN 200
# [22:05:31] seed sp_P10582_DPOM_MAIZE (len 929) …
# [22:05:31] skip sp_P10582_DPOM_MAIZE: length 929 > MAX_LEN 200
# [22:05:31] seed tr_Q8EJ52_Q8EJ52_SHEON (len 442) …
# [22:05:31] skip tr_Q8EJ52_Q8EJ52_SHEON: length 442 > MAX_LEN 200
# [22:05:31] seed tr_Q9HXJ0_Q9HXJ0_PSEAE (len 107) …
# [22:05:41] seed tr_Q9KXJ2_Q9KXJ2_STRCO (len 218) …
# [22:05:41] skip tr_Q9KXJ2_Q9KXJ2_STRCO: length 218 > MAX_LEN 200
# [22:05:41] seed tr_Q9I2X5_Q9I2X5_PSEAE (len 532) …
# [22:05:41] skip tr_Q9I2X5_Q9I2X5_PSEAE: length 532 > MAX_LEN 200
# [22:05:41] seed tr_Q9KQE2_Q9KQE2_VIBCH (len 167) …
# [22:05:55] seed tr_Q9ZEV9_Q9ZEV9_KLUIN (len 251) …
# [22:05:55] skip tr_Q9ZEV9_Q9ZEV9_KLUIN: length 251 > MAX_LEN 200
# [22:05:55] done: wrote 120 variants from 20 seeds → notebook_runs/run_low_mask/seed_MT_bacterial_redox/generated_variants.fasta
# Seed set to 42
# [run_low_mask] Running MetaLATTE for seed set 'MT_bacterial_redox'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_low_mask/seed_MT_bacterial_redox/metalatte_predictions.csv
# [run_low_mask] Computing novelty vs seeds for 'MT_bacterial_redox' (threshold: 0.95)
# [run_low_mask] Saved similarity histogram → notebook_runs/run_low_mask/plots/identity_hist_MT_bacterial_redox.png
# [run_low_mask] Running PepMLM for seed set 'MT_bacterial_transformation'
# [22:08:58] loading PepMLM model/tokenizer…
# [22:08:59] device: cpu; threads: 4
# [22:08:59] seed sp_P0CS90_HSP77_YEAST (len 654) …
# [22:08:59] skip sp_P0CS90_HSP77_YEAST: length 654 > MAX_LEN 200
# [22:08:59] seed sp_P0CS91_HSP77_YEASX (len 655) …
# [22:08:59] skip sp_P0CS91_HSP77_YEASX: length 655 > MAX_LEN 200
# [22:08:59] seed sp_P27635_RL10_HUMAN (len 214) …
# [22:08:59] skip sp_P27635_RL10_HUMAN: length 214 > MAX_LEN 200
# [22:08:59] seed sp_Q99383_HRP1_YEAST (len 534) …
# [22:08:59] skip sp_Q99383_HRP1_YEAST: length 534 > MAX_LEN 200
# [22:08:59] seed sp_Q9TXQ1_TNKS1_CAEEL (len 2276) …
# [22:08:59] skip sp_Q9TXQ1_TNKS1_CAEEL: length 2276 > MAX_LEN 200
# [22:08:59] seed sp_Q9ZKJ5_CTKA_HELPJ (len 325) …
# [22:08:59] skip sp_Q9ZKJ5_CTKA_HELPJ: length 325 > MAX_LEN 200
# [22:08:59] seed sp_O74361_CBP7_SCHPO (len 356) …
# [22:08:59] skip sp_O74361_CBP7_SCHPO: length 356 > MAX_LEN 200
# [22:08:59] seed sp_P50133_PTH1R_PIG (len 585) …
# [22:08:59] skip sp_P50133_PTH1R_PIG: length 585 > MAX_LEN 200
# [22:08:59] seed tr_Q39687_Q39687_DAUCA (len 577) …
# [22:08:59] skip tr_Q39687_Q39687_DAUCA: length 577 > MAX_LEN 200
# [22:08:59] seed sp_Q9N0B5_TM266_MACFA (len 531) …
# [22:08:59] skip sp_Q9N0B5_TM266_MACFA: length 531 > MAX_LEN 200
# [22:08:59] seed tr_Q9S7Z4_Q9S7Z4_MARPO (len 548) …
# [22:08:59] skip tr_Q9S7Z4_Q9S7Z4_MARPO: length 548 > MAX_LEN 200
# [22:08:59] seed tr_Q07958_Q07958_HV1 (len 98) …
# [22:09:07] seed tr_Q8KQ19_Q8KQ19_PSEAI (len 461) …
# [22:09:07] skip tr_Q8KQ19_Q8KQ19_PSEAI: length 461 > MAX_LEN 200
# [22:09:07] seed tr_Q8UUG4_Q8UUG4_ALV (len 43) …
# [22:09:12] seed tr_Q9HZY1_Q9HZY1_PSEAE (len 476) …
# [22:09:12] skip tr_Q9HZY1_Q9HZY1_PSEAE: length 476 > MAX_LEN 200
# [22:09:12] done: wrote 40 variants from 15 seeds → notebook_runs/run_low_mask/seed_MT_bacterial_transformation/generated_variants.fasta
# Seed set to 42
# [run_low_mask] Running MetaLATTE for seed set 'MT_bacterial_transformation'
# Some weights of EsmModel were not initialized from the model checkpoint at /workarea/AML_Final_Project/esm2_local/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [warn] unexpected keys (ignored): ['esm_model.embeddings.position_embeddings.weight']
# ✓ wrote notebook_runs/run_low_mask/seed_MT_bacterial_transformation/metalatte_predictions.csv
# [run_low_mask] Computing novelty vs seeds for 'MT_bacterial_transformation' (threshold: 0.95)
# [run_low_mask] Saved similarity histogram → notebook_runs/run_low_mask/plots/identity_hist_MT_bacterial_transformation.png
# [run_low_mask] Saved all variant scores → notebook_runs/run_low_mask/all_variants_with_scores.csv
# [run_low_mask] Saved summary by seed set → notebook_runs/run_low_mask/summary_by_seed.csv
# [run_low_mask] DONE.
#                        seed_set  n_variants  novelty_pct  \
# 0            MT_bacterial_redox         120    97.500000
# 1   MT_bacterial_transformation          40   100.000000
# 2                   cd_specific         160   100.000000
# 3                   hg_specific         120    99.166667
# 4                 pb_mer_operon         120   100.000000
# 5            MT_bacterial_redox         120   100.000000
# 6   MT_bacterial_transformation          40   100.000000
# 7                   cd_specific         160   100.000000
# 8                   hg_specific         120   100.000000
# 9                 pb_mer_operon         120   100.000000
# 10           MT_bacterial_redox         120    33.333333
# 11  MT_bacterial_transformation          40    80.000000
# 12                  cd_specific         160    56.250000
# 13                  hg_specific         120    26.666667
# 14                pb_mer_operon         120    51.666667
#
#     mean_binding_capacity  max_binding_capacity                      run_dir  \
# 0                0.748681              0.998023       notebook_runs/run_base
# 1                0.186109              0.921346       notebook_runs/run_base
# 2                0.516856              0.999596       notebook_runs/run_base
# 3                0.873874              0.995737       notebook_runs/run_base
# 4                0.499947              0.996335       notebook_runs/run_base
# 5                0.669328              0.998815  notebook_runs/run_high_mask
# 6                0.244565              0.987552  notebook_runs/run_high_mask
# 7                0.418183              0.998927  notebook_runs/run_high_mask
# 8                0.525037              0.996271  notebook_runs/run_high_mask
# 9                0.301751              0.997604  notebook_runs/run_high_mask
# 10               0.823064              0.998011   notebook_runs/run_low_mask
# 11               0.180742              0.920273   notebook_runs/run_low_mask
# 12               0.580473              0.999769   notebook_runs/run_low_mask
# 13               0.963856              0.994029   notebook_runs/run_low_mask
# 14               0.514274              0.995961   notebook_runs/run_low_mask
#
#          run_name
# 0        run_base
# 1        run_base
# 2        run_base
# 3        run_base
# 4        run_base
# 5   run_high_mask
# 6   run_high_mask
# 7   run_high_mask
# 8   run_high_mask
# 9   run_high_mask
# 10   run_low_mask
# 11   run_low_mask
# 12   run_low_mask
# 13   run_low_mask
# 14   run_low_mask

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

base_dir = Path("notebook_runs")
run_dirs = ["run_base", "run_high_mask", "run_low_mask"]

dfs = []
for rd in run_dirs:
    csv_path = base_dir / rd / "all_variants_with_scores.csv"
    df = pd.read_csv(csv_path)
    # make sure run_name is present / correct
    df["run_name"] = rd
    dfs.append(df)

all_variants = pd.concat(dfs, ignore_index=True)
print(all_variants.columns)
len(all_variants)
# Out:
# Index(['id', 'sequence', 'prob_Ag', 'prob_Cd', 'prob_Co', 'prob_Cu', 'prob_Fe',
#        'prob_Hg', 'prob_Mn', 'prob_Mo', 'prob_Ni', 'prob_Non-binding',
#        'prob_Pb', 'prob_Pt', 'prob_V', 'prob_W', 'prob_Zn', 'binding_capacity',
#        'best_metal', 'max_identity_to_seed', 'is_novel', 'seed_set',
#        'run_name'],
#       dtype='object')
# 1680

# %%
def plot_novelty_vs_binding_by_metal(
    df: pd.DataFrame,
    run_name: str | None = None,
    top_n_per_seed: int | None = None,
):
    """
    Scatter plot of novelty vs binding_capacity, colored by best_metal.
    - If run_name is given, filter to that run.
    - If top_n_per_seed is given, keep only that many top binders per (run, seed_set).
    """
    data = df.copy()

    if run_name is not None:
        data = data[data["run_name"] == run_name]

    if "max_identity_to_seed" not in data.columns:
        raise ValueError("Expected 'max_identity_to_seed' column. "
                         "This exists in the original pipeline outputs.")

    # Optional: restrict to top-N by binding per run/seed_set to reduce clutter
    if top_n_per_seed is not None:
        data = (
            data.sort_values("binding_capacity", ascending=False)
                .groupby(["run_name", "seed_set"])
                .head(top_n_per_seed)
        )

    # Novelty as (1 - identity): 0 = identical to seeds, 1 = very different
    data["novelty"] = 1.0 - data["max_identity_to_seed"]

    plt.figure(figsize=(7, 5))

    metals = sorted(data["best_metal"].dropna().unique())
    for metal in metals:
        sub = data[data["best_metal"] == metal]
        plt.scatter(
            sub["novelty"],
            sub["binding_capacity"],
            label=metal,
            alpha=0.6,
            s=20,
        )

    title = "Novelty vs binding capacity by metal"
    if run_name is not None:
        title += f" ({run_name})"

    plt.xlabel("Novelty (1 - max identity to any seed)")
    plt.ylabel("Binding capacity")
    plt.title(title)
    plt.legend(title="Best metal", bbox_to_anchor=(1.05, 1), loc="upper left")
    plt.tight_layout()
    plt.show()

# %%
plot_novelty_vs_binding_by_metal(all_variants, top_n_per_seed=200)

# %%
for rd in run_dirs:
    plot_novelty_vs_binding_by_metal(all_variants, run_name=rd, top_n_per_seed=200)
